# %% [markdown]
# <a href="https://colab.research.google.com/github/manishmmj/anime_reccomendation/blob/main/Amazon_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Install PySpark (Python API for Spark)
# !pip install -q pyspark

# %%
# Download Spark
# !wget -q https://archive.apache.org/dist/spark/spark-3.5.0/spark-3.5.0-bin-hadoop3.tgz

# %%
# Install Java (Spark needs Java to run)
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
# Out:
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/universe/o/openjdk-8/openjdk-8-jre-headless_8u472-ga-1%7e22.04_amd64.deb  404  Not Found [IP: 91.189.91.81 80]
# E: Failed to fetch http://security.ubuntu.com/ubuntu/pool/universe/o/openjdk-8/openjdk-8-jdk-headless_8u472-ga-1%7e22.04_amd64.deb  404  Not Found [IP: 91.189.91.81 80]
# E: Unable to fetch some archives, maybe run apt-get update or try with --fix-missing?

# %%
# Extract the downloaded Spark file
# !tar xf spark-3.5.0-bin-hadoop3.tgz

# %%
import os  # Used to set system environment variables

# Set Java path (required for Spark to run)
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"

# Set Spark path (where Spark is installed)
os.environ["SPARK_HOME"] = "/content/spark-3.5.0-bin-hadoop3"

# %%
from pyspark.sql import SparkSession  # Import SparkSession (main entry point of Spark)

# Create a Spark session (this starts Spark engine)
spark = SparkSession.builder.appName("Sales Prediction System").getOrCreate()

# Print confirmation message
print("Spark Started Successfully 🚀")
# Out:
# ---------------------------------------------------------------------------
# PySparkRuntimeError                       Traceback (most recent call last)
# /tmp/ipython-input-1043701864.py in <cell line: 0>()
#       2
#       3 # Create a Spark session (this starts Spark engine)
# ----> 4 spark = SparkSession.builder.appName("Sales Prediction System").getOrCreate()
#       5
#       6 # Print confirmation message
#
# /usr/local/lib/python3.12/dist-packages/pyspark/sql/session.py in getOrCreate(self)
#     555                         sparkConf.set(key, value)
#     556                     # This SparkContext may be an existing one.
# --> 557                     sc = SparkContext.getOrCreate(sparkConf)
#     558                     # Do not update `SparkConf` for existing `SparkContext`, as it's shared
#     559                     # by all sessions.
#
# /usr/local/lib/python3.12/dist-packages/pyspark/core/context.py in getOrCreate(cls, conf)
# ...

# %%
import kagglehub
df = kagglehub.dataset_download("karkavelrajaj/amazon-sales-dataset")
